# %% [markdown]
# ## Case study: Screw driving data
#
# The provided .rar contains 500 JSON files. Each file corresponds to a single screw run, recorded on a machine here at the IPS.

# %% [markdown]
# <img src=images/plot_nok_example.png height=500>
#
#
# <img src=images/plot_ok_example.png height=500>

# %%
{
	"format":	"channel",
	"node id":	"0.1",
	"nr":	1,
	"result":	"NOK",
	"hardware":	"CS351 ",
	"mac0":	"00-C0-3A-6E-9c-8e",
	"ip0":	"129.217.174.137",
	"sw version":	"2.500",
	"sw build":	"SP1",
	"MCE factor":	1,
	"MCE":	[{
			"Transducer function":	"primary",
			"measuring":	"direct",
			"factor":	1
		}],
	"max. speed":	783,
	"location name":	["1", "2", "3", "4", "5", "6", "7"],
	"channel":	"",
	"prg nr":	0,
	"prg name":	"SMW_4step",
	"prg date":	"2022-12-19 15:48:16",
	"cycle":	1613073,
	"redundancy sensor":	-1,
	"nominal torque":	6,
	"date":	"2023-09-29 17:19:55",
	"id code":	"30000000009767",
	"torque unit":	"Nm",
	"last cmd":	"MFs AngleMax",
	"last step row":	"4",
	"last step column":	"A",
	"quality code":	"    2",
	"total time":	"1.5",
	"tool serial":	955000040,
	"redundancy transducer serial":	2147483648,
	"spindle id":	"",
	"rework code":	0,
	"rework text":	"",
	"batch nr":	-1,
	"batch canceled":	-1,
	"batch direction OK":	-1,
	"batch direction NOK":	-1,
	"batch max OK":	-1,
	"batch OK":	-1,
	"batch max NOK":	-1,
	"batch NOK":	-1,
	"angle global threshold":	{
		"nom":	0,
		"act":	0.003000
	},
	"Torque CT":	0.975000,
	"Torque Cred":	1,
	"tightening steps":	[{
			"step type":	"standard",
			"row":	"2",
			"column":	"A",
			"name":	"Finding",
			"last cmd":	"TF Angle",
			"quality code":	"    1",
			"speed":	150,
			"category":	0,
			"docu buffer":	0,
			"result":	"OK",
			"angle threshold":	{
				"nom":	0,
				"act":	-0.003000
			},
			"tightening functions":	[{
					"name":	"TF Angle",
					"nom":	100,
					"act":	100.750000,
					"add":	[{
							"angle threshold":	{
								"nom":	0,
								"act":	-0.003000
							}
						}]
				}, {
					"name":	"MFs TimeMax",
					"nom":	5,
					"act":	0.110000
				}, {
					"name":	"MF TorqueMin",
					"nom":	0,
					"act":	0.035000
				}, {
					"name":	"MFs TorqueMax",
					"nom":	1.200000,
					"act":	0.035000
				}],
			"graph":	{
				"angle values":	[0, ..., 100.750000],
				"torque values":	[-0.003000, ... 0.035000],
				"gradient values":	[0, ..., -0.005100],
				"torqueRed values":	[0, ... 0],
				"angleRed values":	[0, ..., 0],
				"time values":	[0, 0.001200, ..., 0.111600]
			}
		}, {
			"step type":	"standard",
			"row":	"3",
			"column":	"A",
			"name":	"Thread forming",
			"last cmd":	"TF Angle",
			"quality code":	"    1",
			"speed":	600,
			"category":	1,
			"docu buffer":	2,
			"result":	"OK",
			"angle threshold":	{
				"nom":	0,
				"act":	0.035000
			},
			"tightening functions":	[{
					"name":	"TF Angle",
					"nom":	1400,
					"act":	1400.500000,
					"add":	[{
							"angle threshold":	{
								"nom":	0,
								"act":	0.035000
							}
						}]
				}, {
					"name":	"MFs TimeMax",
					"nom":	10,
					"act":	0.390000
				}, {
					"name":	"MF TorqueMin",
					"nom":	-0.100000,
					"act":	0.049000
				}, {
					"name":	"MFs TorqueMax",
					"nom":	1.200000,
					"act":	0.049000
				}, {
					"name":	"MF AngleMin",
					"nom":	0,
					"act":	1400.500000,
					"add":	[{
							"angle threshold":	{
								"nom":	0,
								"act":	0.035000
							}
						}]
				}, {
					"name":	"MFs AngleMax",
					"nom":	2000,
					"act":	1400.500000,
					"add":	[{
							"angle threshold":	{
								"nom":	0,
								"act":	0.035000
							}
						}]
				}],
			"graph":	{
				"angle values":	[100.750000, ..., 1501.250000],
				"torque values":	[0.035000, ..., 0.049000],
				"gradient values":	[-0.005100, ..., -0.003200],
				"torqueRed values":	[0, ..., 0],
				"angleRed values":	[0, ..., 0],
				"time values":	[0.111600, ..., 0.501600]
			}
		}, {
			"step type":	"standard",
			"row":	"4",
			"column":	"A",
			"name":	"Pre-tightening",
			"last cmd":	"MFs AngleMax",
			"quality code":	"    2",
			"speed":	200,
			"category":	0,
			"docu buffer":	1,
			"result":	"NOK",
			"angle threshold":	{
				"nom":	0,
				"act":	0.049000
			},
			"tightening functions":	[{
					"name":	"TF Torque",
					"nom":	1.100000,
					"act":	0.115000
				}, {
					"name":	"MFs TimeMax",
					"nom":	10,
					"act":	0.830000
				}, {
					"name":	"MF TorqueMin",
					"nom":	-0.100000,
					"act":	0.115000
				}, {
					"name":	"MFs TorqueMax",
					"nom":	1.200000,
					"act":	0.115000
				}, {
					"name":	"MF AngleMin",
					"nom":	0,
					"act":	1006,
					"add":	[{
							"angle threshold":	{
								"nom":	0,
								"act":	0.049000
							}
						}]
				}, {
					"name":	"MFs AngleMax",
					"nom":	1000,
					"act":	1006,
					"add":	[{
							"angle threshold":	{
								"nom":	0,
								"act":	0.049000
							}
						}]
				}],
			"graph":	{
				"torsion release":	15,
				"angle values":	[1501.250000, ..., 2506],
				"torque values":	[0.049000, ..., -0.009000],
				"gradient values":	[-0.003200, ..., -0.015400],
				"torqueRed values":	[0, ..., 0],
				"angleRed values":	[0, ..., 0],
				"time values":	[0.501600, ..., 1.453200]
			}
		}]
}

# %% [markdown]
# # Case study
#
# Today, we have two simple goals now for the data:
#
# 1. Explore the data using data visualizations.
#
# 2. Prepare the data (`torque values`) in a numpy array for tomorrw's analysis.
